# %%
# IMPORT DEPENDENCIES
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st
from datetime import datetime

# %%
# SET PATHS TO DATA
end_use = 'datasets/clean_data/end_use_of_energy_products.csv'
natural_inputs = 'datasets/clean_data/energy_from_natural_inputs.csv'
indicators = 'datasets/clean_data/energy_indicators.csv'
stocks = 'datasets/clean_data/energy_stocks.csv'
detailed_supply = 'datasets/clean_data/mining_detailed_supply.csv'
gender = 'datasets/clean_data/mining_gender.csv'
production = 'datasets/clean_data/production_of_energy_products.csv'
transformation = 'datasets/clean_data/transformation_of_energy_products.csv'

# %%
# READ IN DATA
end_use = pd.read_csv(end_use)
natural_inputs = pd.read_csv(natural_inputs)
indicators = pd.read_csv(indicators)
stocks = pd.read_csv(stocks)
detailed_supply = pd.read_csv(detailed_supply)
gender = pd.read_csv(gender)
production = pd.read_csv(production)
transformation = pd.read_csv(transformation)

# %%
end_use.head(1)
# Out:
#     Commodity  Agriculture, forestry and fishing  Mining  Manufacturing  \
# 0  Black coal                                  0       0            105
#
#    Electricity, gas, water and waste services  Construction  \
# 0                                           0             0
#
#    Commercial and Services
# 0                        0

# %%
natural_inputs.head(1)
# Out:
#     Commodity  Agriculture, forestry and fishing  Mining  Manufacturing  \
# 0  Black coal                                  0  12,370              0
#
#    Electricity, gas, water and waste services  Construction  \
# 0                                           0             0
#
#    Commercial and Services
# 0                        0

# %%
indicators.head(1)
# Out:
#    Date  Net energy use index  GDP, Chain volume series - Index  \
# 0  2003                 100.0                             100.0
#
#    Degree of self sufficiency  \
# 0                       307.0
#
#    Renewable energy supply of total domestic net energy use  \
# 0                                                8.5
#
#    Share of renewable energy in net energy inputs  \
# 0                                             1.7
#
#    Government use of net domestic energy  \
# 0                                    2.6
#
#   Estimated resident population - Australia  \
# 0                              19,720,737.0
#
#   Estimated number of households -  Australia  Energy use (Net) - per person  \
# 0                                 7,264,723.0                           55.7
#
#    Energy use (Net) - per household  Gas costs - per household  \
# 0                             151.3                        0.0
#
#   Petroleum costs - per household Electricity costs - per household  \
# 0                               0                                 0
#
#   Total energy costs - per household  Energy extracted (Net) - per household  \
# 0                                  0                                     6.3
#
#    Renewable energy extracted by households
# 0                                      45.9

# %%
stocks.head(1)
# Out:
#     Commodity Unit       2002       2003       2004       2005       2006  \
# 0  Black Coal   PJ  1,053,000  1,063,800  1,074,600  1,063,800  1,061,100
#
#         2007       2008       2009       2010       2011       2012  \
# 0  1,055,700  1,120,500  1,155,600  1,341,900  1,601,100  1,663,200
#
#         2013       2014       2015       2016       2017       2018
# 0  1,676,700  1,760,400  1,879,200  2,138,400  2,454,300  2,659,500

# %%
detailed_supply.head(1)
# Out:
#                   Input   Commodity   2002   2003   2004   2005   2006   2007  \
# 0  Production of Energy  Black coal  7,287  7,535  8,055  8,141  8,632  8,651
#
#     2008   2009   2010   2011    2012    2013    2014    2015    2016    2017
# 0  9,009  9,759  9,244  9,885  10,902  11,807  12,288  12,157  12,162  12,370

# %%
gender.head(1)
# Out:
#    Date    Sex Location Employed full-time ('000) Employed part-time ('000)
# 0  2002  Males      NSW                1.39163482                         0

# %%
production.head(1)
# Out:
#     Commodity  Agriculture, forestry and fishing  Mining  Manufacturing  \
# 0  Black coal                                  0  12,370              0
#
#    Electricity, gas, water and waste services  Construction  \
# 0                                           0             0
#
#    Commercial and Services
# 0                        0

# %%
transformation.head(1)
# Out:
#     Commodity  Agriculture, forestry and fishing Mining Manufacturing  \
# 0  Black coal                                  0      4           115
#
#   Electricity, gas, water and waste services  Construction  \
# 0                                      1,164             0
#
#    Commercial and Services
# 0                        0
