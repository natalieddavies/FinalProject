# %%
# IMPORT DEPENDENCIES
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st
from datetime import datetime

# %%
# SET PATHS TO DATA
path_data1 = 'datasets/cleandata/energy_indicators.csv'
# path_data2 = 'AusEnergyIndicators.csv'
# path_data3 = 'AusEnergyStocks.csv'
# path_data4 = 'AusGrossPhysicalSupUse.csv'
# path_data5 = 'DetailedSup.csv'
# path_data6 = 'EmploymentStateGenderContract.csv'
# path_data7 = 'NetSup20172018.csv'

# %%
path1 = pd.read_csv(path_data1)

# %%
path1
# Out:
#                Australian Bureau of Statistics  Net energy use index  \
# 0                                       Jun-03                 100.0
# 1                                       Jun-04                 101.3
# 2                                       Jun-05                 109.6
# 3                                       Jun-06                 108.1
# 4                                       Jun-07                 112.6
# 5                                       Jun-08                 115.2
# 6                                       Jun-09                 119.2
# 7                                       Jun-10                 116.0
# 8                                       Jun-11                 114.8
# 9                                       Jun-12                 119.0
# 10                                      Jun-13                 130.2
# 11                                      Jun-14                 127.2
# 12                                      Jun-15                 132.0
# 13                                      Jun-16                 138.6
# 14                                      Jun-17                 141.4
# 15                                      Jun-18                 144.4
#
#     GDP, Chain volume series - Index  Degree of self sufficiency  \
# 0                              100.0                       307.0
# 1                              104.1                       303.8
# 2                              107.4                       320.5
# 3                              110.4                       305.9
# 4                              114.6                       307.7
# 5                              118.8                       311.8
# 6                              121.1                       315.4
# 7                              123.6                       304.4
# 8                              126.7                       293.9
# 9                              131.6                       306.2
# 10                             135.0                       334.6
# 11                             138.5                       327.6
# 12                             141.5                       340.0
# 13                             145.4                       350.2
# 14                             148.9                       352.5
# 15                             153.2                       355.8
#
#     Renewable energy supply of total domestic net energy use  \
# 0                                                 8.5
# 1                                                 8.3
# 2                                                 8.2
# 3                                                 8.2
# 4                                                 8.1
# 5                                                 7.9
# 6                                                 6.6
# 7                                                 7.7
# 8                                                 7.8
# 9                                                 7.6
# 10                                                8.5
# 11                                                8.7
# 12                                                8.8
# 13                                                8.8
# 14                                                9.2
# 15                                                9.1
#
#     Share of renewable energy in net energy inputs  \
# 0                                              1.7
# 1                                              1.6
# 2                                              1.5
# 3                                              1.6
# 4                                              1.5
# 5                                              1.5
# 6                                              1.2
# 7                                              1.5
# 8                                              1.5
# 9                                              1.5
# 10                                             1.5
# 11                                             1.6
# 12                                             1.6
# 13                                             1.6
# 14                                             1.6
# 15                                             1.6
#
#     Government use of net domestic energy  \
# 0                                     2.6
# 1                                     2.6
# 2                                     2.5
# 3                                     2.5
# 4                                     2.5
# 5                                     2.5
# 6                                     2.5
# 7                                     2.6
# 8                                     2.6
# 9                                     2.6
# 10                                    2.6
# 11                                    2.7
# 12                                    2.7
# 13                                    2.7
# 14                                    2.7
# 15                                    2.7
#
#     Estimated resident population - Australia  \
# 0                                    19720737
# 1                                    19932722
# 2                                    20176844
# 3                                    20450966
# 4                                    20827622
# 5                                    21249199
# 6                                    21691653
# 7                                    22031750
# 8                                    22340024
# 9                                    22733465
# 10                                   23128129
# 11                                   23475686
# 12                                   23815995
# 13                                   24190907
# 14                                   24601860
# 15                                   24992747
#
#     Estimated number of households -  Australia  \
# 0                                       7264723
# 1                                       7396137
# 2                                       7526410
# 3                                       7656969
# 4                                       7803641
# 5                                       7953657
# 6                                       8106022
# 7                                       8262019
# 8                                       8419972
# 9                                       8576293
# 10                                      8737962
# 11                                      8902436
# 12                                      9072188
# 13                                      9204635
# 14                                      9345350
# 15                                      9495177
#
#     Energy use (Net) - per person  ...  LPG (Remaining resource life)  \
# 0                            55.7  ...                           38.2
# 1                            56.6  ...                           40.3
# 2                            55.8  ...                           25.1
# 3                            55.7  ...                           25.6
# 4                            55.1  ...                           27.5
# 5                            54.4  ...                           22.6
# 6                            53.2  ...                           55.8
# 7                            53.0  ...                           47.8
# 8                            53.7  ...                           52.1
# 9                            53.1  ...                           51.6
# 10                           52.9  ...                           54.0
# 11                           52.2  ...                           46.9
# 12                           52.6  ...                           46.6
# 13                           51.4  ...                           50.5
# 14                           51.5  ...                           52.9
# 15                           51.4  ...                           64.8
#
#     0tural gas (Remaining resource life)  Uranium (remaining resource life)  \
# 0                                   71.9                               74.1
# 1                                   61.9                               71.7
# 2                                   64.4                               74.6
# 3                                   58.2                               94.1
# 4                                   50.1                               98.7
# 5                                   58.0                              127.7
# 6                                   79.9                              149.1
# 7                                   71.0                              201.8
# 8                                   61.8                              199.2
# 9                                   62.6                              169.1
# 10                                  49.0                              182.9
# 11                                  52.0                              231.8
# 12                                  56.8                              217.7
# 13                                  55.2                              202.9
# 14                                  29.5                              175.3
# 15                                  26.7                              197.4
#
#     Black coal (Extraction rate)  Brown coal (Extraction rate)  \
# 0                            0.7                           0.2
# 1                            0.7                           0.2
# 2                            0.8                           0.2
# 3                            0.8                           0.2
# 4                            0.8                           0.2
# 5                            0.8                           0.2
# 6                            0.8                           0.2
# 7                            0.9                           0.2
# 8                            0.7                           0.2
# 9                            0.6                           0.2
# 10                           0.6                           0.1
# 11                           0.7                           0.1
# 12                           0.7                           0.1
# 13                           0.6                           0.1
# 14                           0.6                           0.1
# 15                           0.5                           0.1
#
#     Crude oil (Extraction rate)  Condensate (Extraction rate)  \
# 0                          11.9                           3.0
# 1                          10.1                           3.0
# 2                           9.3                           2.4
# 3                          10.0                           2.7
# 4                          11.9                           3.4
# 5                           9.7                           3.1
# 6                           9.9                           1.8
# 7                           9.3                           2.2
# 8                          10.0                           2.1
# 9                           9.3                           1.9
# 10                          6.8                           2.1
# 11                          6.2                           2.1
# 12                          9.3                           2.1
# 13                          8.8                           2.1
# 14                          7.0                           2.2
# 15                          6.4                           2.2
#
#     LPG (Extraction rate)  0tural gas (Extraction rate)  \
# 0                     2.6                           1.4
# 1                     2.5                           1.6
# 2                     4.0                           1.6
# 3                     3.9                           1.7
# 4                     3.6                           2.0
# 5                     4.4                           1.7
# 6                     1.8                           1.3
# 7                     2.1                           1.4
# 8                     1.9                           1.6
# 9                     1.9                           1.6
# 10                    1.9                           2.0
# 11                    2.1                           1.9
# 12                    2.1                           1.8
# 13                    2.0                           1.8
# 14                    1.9                           3.4
# 15                    1.5                           3.7
#
#     Uranium (Extraction rate)
# 0                         1.3
# 1                         1.4
# 2                         1.3
# 3                         1.1
# 4                         1.0
# 5                         0.8
# 6                         0.7
# 7                         0.5
# 8                         0.5
# 9                         0.6
# 10                        0.5
# 11                        0.4
# 12                        0.5
# 13                        0.5
# 14                        0.6
# 15                        0.5
#
# [16 rows x 39 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-ce43c219a2fd> in <module>
# ----> 1 path1 = path1[1].dt.strftime("%m/%d/%y")
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
